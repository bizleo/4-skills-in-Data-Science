# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
death.head()
#this data set contains the number of death people per day in each country until 24.01.2022.
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/17/22  1/18/22  1/19/22  \
# 0        0        0        0        0  ...     7381     7383     7386
# 1        0        0        0        0  ...     3271     3277     3283
# 2        0        0        0        0  ...     6423     6435     6443
# 3        0        0        0        0  ...      142      142      142
# 4        0        0        0        0  ...     1866     1870     1877
#
#    1/20/22  1/21/22  1/22/22  1/23/22  1/24/22  1/25/22  1/26/22
# ...

# %%
death['Sum of death'] = death.loc[ : ,'1/22/20':'1/24/22'].sum(axis=1)

# %%
death['Sum of death']
# Out:
# 0      2252429
# 1      1037798
# 2      2094848
# 3        63535
# 4       449603
#         ...
# 275    3779231
# 276    1445812
# 277     637580
# 278     994849
# 279    1190731
# Name: Sum of death, Length: 280, dtype: int64

# %%
death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Columns: 741 entries, Province/State to Sum of death
# dtypes: float64(2), int64(737), object(2)
# memory usage: 1.6+ MB

# %%
death.drop(['Province/State'], axis = 1)
# Out:
#          Country/Region        Lat        Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.939110   67.709953        0        0        0
# 1               Albania  41.153300   20.168300        0        0        0
# 2               Algeria  28.033900    1.659600        0        0        0
# 3               Andorra  42.506300    1.521800        0        0        0
# 4                Angola -11.202700   17.873900        0        0        0
# ..                  ...        ...         ...      ...      ...      ...
# 275             Vietnam  14.058324  108.277199        0        0        0
# 276  West Bank and Gaza  31.952200   35.233200        0        0        0
# 277               Yemen  15.552727   48.516388        0        0        0
# 278              Zambia -13.133897   27.849332        0        0        0
# 279            Zimbabwe -19.015438   29.154857        0        0        0
#
#      1/25/20  1/26/20  1/27/20  1/28/20  ...  1/18/22  1/19/22  1/20/22  \
# ...

# %%
zimb = death.loc[279:279,'1/22/20':'1/24/22']
zimba = death.iloc[279, 4:-1]


lista = range(0,len(zimba))
    
plt.plot(lista, zimba)
plt.show()

# %%
death.plot(x="Long", y="Lat", kind="scatter", c="Sum of death",
        colormap="YlOrRd")
# Out:
# <AxesSubplot:xlabel='Long', ylabel='Lat'>

# %%
death['Sum of death'].sort_values( ascending = False).head().plot.bar()
#set_xlabel(['US', 'BR' ,'dd' , 'dd', 'd'  ])
# Out:
# <AxesSubplot:>

# %%
death['Sum of death'].sort_values( ascending = False).head()
# Out:
# 255    291692885
# 30     211588194
# 147    150205232
# 183    107485190
# 211     82871322
# Name: Sum of death, dtype: int64
